# %%
message_to_encrypted = bytes(input(), 'utf-8')
# Out:
# We aer all going1!1 we have PLENTY of wine!!!!

# %%
pip install eciespy
# Out:
# ...
#      |████████████████████████████████| 522kB 3.9MB/s
# ...
#      |████████████████████████████████| 13.7MB 307kB/s
# ...
#      |████████████████████████████████| 112kB 49.5MB/s
# ...
#      |████████████████████████████████| 481kB 45.2MB/s
# ...
#   Created wheel for cytoolz: filename=cytoolz-0.10.1-cp36-cp36m-linux_x86_64.whl size=1233718 sha256=510831aa248feb9c4c920d54056fb3c282b1725fe4f804092dbee7b2a120a1c5
#   Stored in directory: /root/.cache/pip/wheels/64/2a/18/d962b614e055577e7d9a3e4813e0742f822ca9c8800cc3783a
# Successfully built cytoolz
# ...

# %%
from ecies import encrypt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
with open("/content/drive/My Drive/Colab Notebooks/ECC/public_key/pub", "r") as public_key:
  public = public_key.read()

# %%
encripted_msg = encrypt(public, message_to_encrypted)

# %%
with open("/content/drive/My Drive/Colab Notebooks/ECC/responses/response", "wb") as response:
  response.write(encripted_msg)
